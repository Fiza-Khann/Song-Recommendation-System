# %%
#Project_Python
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')

import os
import tensorflow as tf
import keras
import cv2

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers , models, optimizers

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.applications import ResNet50V2

# %%
train_dir = 'train/'
test_dir = 'test/'

def Classes_Count( path, name):
    Classes_Dict = {}
    
    for Class in os.listdir(path):
        
        Full_Path = path + Class
        Classes_Dict[Class] = len(os.listdir(Full_Path))
        
    df = pd.DataFrame(Classes_Dict, index=[name])
    
    return df

Train_Count = Classes_Count(train_dir, 'Train').transpose().sort_values(by="Train", ascending=False)
Test_Count = Classes_Count(test_dir, 'Test').transpose().sort_values(by="Test", ascending=False)

# %%
pd.concat([Train_Count,Test_Count] , axis=1)
# Out:
#           Train  Test
# happy      7215  1774
# neutral    4965  1233
# sad        4830  1247
# fear       4097  1024
# angry      3995   958
# surprise   3171   831
# disgust     436   111

# %%
Train_Count.plot(kind='barh')
# Out:
# <Axes: >

# %%
Test_Count.plot(kind='barh')
# Out:
# <Axes: >

# %%
plt.style.use('default')
plt.figure(figsize = (25, 8))
image_count = 1
BASE_URL = 'train/'

for directory in os.listdir(BASE_URL):
    if directory[0] != '.':
        for i, file in enumerate(os.listdir(BASE_URL + directory)):
            if i == 1:
                break
            else:
                fig = plt.subplot(1, 7, image_count)
                image_count += 1
                image = cv2.imread(BASE_URL + directory + '/' + file)
                plt.imshow(image)
                plt.title(directory, fontsize = 20)

# %%
img_shape = 48
batch_size = 64
train_data_path = 'train/'
test_data_path = 'test/'

# %%
train_preprocessor = ImageDataGenerator(
        rescale = 1 / 255.,
        # Data Augmentation
        rotation_range=10,
        zoom_range=0.2,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,                                        
        fill_mode='nearest',
    )


test_preprocessor = ImageDataGenerator(
    rescale = 1 / 255.,
)

train_data = train_preprocessor.flow_from_directory(
    train_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode='rgb', 
    shuffle=True,
    batch_size=batch_size,
    subset='training', 
)


test_data = test_preprocessor.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode="rgb",
    shuffle=False,
    batch_size=batch_size,
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
def Create_CNN_Model():
    
    model = Sequential()
    
    #CNN1
    model.add(Conv2D(32, (3,3), activation='relu', input_shape=(img_shape, img_shape, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(64,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    #CNN2
    model.add(Conv2D(64, (3,3), activation='relu', ))
    model.add(BatchNormalization())
    model.add(Conv2D(128,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    #CNN3
    model.add(Conv2D(128, (3,3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    
    #Output
    model.add(Flatten())
    
    model.add(Dense(1024, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(7,activation='softmax'))
    
    
    return model

# %%
CNN_Model = Create_CNN_Model()

CNN_Model.summary()

CNN_Model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# c:\Users\ESHOP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 46, 46, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 46, 46, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 46, 46, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 21, 21, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 21, 21, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 21, 21, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 21, 21, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 11, 11, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 11, 11, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 9, 9, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 9, 9, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 9, 9, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 9, 9, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     6,554,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,837,895 (29.90 MB)
#  Trainable params: 7,832,519 (29.88 MB)
#  Non-trainable params: 5,376 (21.00 KB)

# %%
# Create Callback Checkpoint
checkpoint_path = "CNN_Model_Checkpoint.keras"

Checkpoint = ModelCheckpoint(checkpoint_path, monitor="val_accuracy", save_best_only=True)

# Create Early Stopping Callback to monitor the accuracy
Early_Stopping = EarlyStopping(monitor = 'val_accuracy', patience = 15, restore_best_weights = True, verbose=1)

# Create ReduceLROnPlateau Callback to reduce overfitting by decreasing learning rate
Reducing_LR = tf.keras.callbacks.ReduceLROnPlateau( monitor='val_loss',
                                                  factor=0.2,
                                                  patience=2,
#                                                   min_lr=0.000005,
                                                  verbose=1)

callbacks = [Early_Stopping, Reducing_LR]

steps_per_epoch = train_data.n // train_data.batch_size
validation_steps = test_data.n // test_data.batch_size

# %%
CNN_history = CNN_Model.fit( train_data , validation_data= test_data , epochs=50, batch_size= batch_size,
                            callbacks=callbacks, steps_per_epoch= steps_per_epoch, validation_steps=validation_steps)
# Out:
# c:\Users\ESHOP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2243s 5s/step - accuracy: 0.1832 - loss: 2.2724 - val_accuracy: 0.2504 - val_loss: 1.8369 - learning_rate: 0.0010
# Epoch 2/50
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 15:37 2s/step - accuracy: 0.1875 - loss: 1.8848
# c:\Users\ESHOP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 79s 172ms/step - accuracy: 0.1875 - loss: 1.8848 - val_accuracy: 0.2511 - val_loss: 1.8355 - learning_rate: 0.0010
# Epoch 3/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2625s 6s/step - accuracy: 0.2382 - loss: 1.8357 - val_accuracy: 0.3114 - val_loss: 1.6696 - learning_rate: 0.0010
# Epoch 4/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 121ms/step - accuracy: 0.2500 - loss: 1.7803 - val_accuracy: 0.3096 - val_loss: 1.6726 - learning_rate: 0.0010
# Epoch 5/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1047s 2s/step - accuracy: 0.2995 - loss: 1.7165 - val_accuracy: 0.3584 - val_loss: 1.6008 - learning_rate: 0.0010
# Epoch 6/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 52s 112ms/step - accuracy: 0.3438 - loss: 1.6745 - val_accuracy: 0.3624 - val_loss: 1.5899 - learning_rate: 0.0010
# Epoch 7/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 35613s 80s/step - accuracy: 0.3650 - loss: 1.6076 - val_accuracy: 0.4418 - val_loss: 1.4317 - learning_rate: 0.0010
# Epoch 8/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 31s 65ms/step - accuracy: 0.3438 - loss: 1.7156 - val_accuracy: 0.4443 - val_loss: 1.4293 - learning_rate: 0.0010
# Epoch 9/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 892s 2s/step - accuracy: 0.4179 - loss: 1.4939 - val_accuracy: 0.3883 - val_loss: 1.6017 - learning_rate: 0.0010
# Epoch 10/50
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 11:14 2s/step - accuracy: 0.3750 - loss: 1.5982
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 34s 74ms/step - accuracy: 0.3750 - loss: 1.5982 - val_accuracy: 0.3694 - val_loss: 1.6579 - learning_rate: 0.0010
# Epoch 11/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 776s 2s/step - accuracy: 0.4765 - loss: 1.3856 - val_accuracy: 0.5137 - val_loss: 1.2925 - learning_rate: 2.0000e-04
# Epoch 12/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 49s 104ms/step - accuracy: 0.4688 - loss: 1.2940 - val_accuracy: 0.5137 - val_loss: 1.2893 - learning_rate: 2.0000e-04
# Epoch 13/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2631s 6s/step - accuracy: 0.4945 - loss: 1.3400 - val_accuracy: 0.5449 - val_loss: 1.1949 - learning_rate: 2.0000e-04
# Epoch 14/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 74s 159ms/step - accuracy: 0.6406 - loss: 1.1774 - val_accuracy: 0.5466 - val_loss: 1.1952 - learning_rate: 2.0000e-04
# Epoch 15/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5075 - loss: 1.3124
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1438s 3s/step - accuracy: 0.5075 - loss: 1.3124 - val_accuracy: 0.5318 - val_loss: 1.2099 - learning_rate: 2.0000e-04
# Epoch 16/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 49s 105ms/step - accuracy: 0.4219 - loss: 1.3075 - val_accuracy: 0.5325 - val_loss: 1.2092 - learning_rate: 4.0000e-05
# Epoch 17/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1537s 3s/step - accuracy: 0.5176 - loss: 1.2838 - val_accuracy: 0.5571 - val_loss: 1.1647 - learning_rate: 4.0000e-05
# Epoch 18/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 82s 178ms/step - accuracy: 0.5312 - loss: 1.3070 - val_accuracy: 0.5561 - val_loss: 1.1646 - learning_rate: 4.0000e-05
# Epoch 19/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1328s 3s/step - accuracy: 0.5341 - loss: 1.2534 - val_accuracy: 0.5647 - val_loss: 1.1424 - learning_rate: 4.0000e-05
# Epoch 20/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 68s 145ms/step - accuracy: 0.5469 - loss: 1.2755 - val_accuracy: 0.5649 - val_loss: 1.1425 - learning_rate: 4.0000e-05
# Epoch 21/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1304s 3s/step - accuracy: 0.5323 - loss: 1.2533 - val_accuracy: 0.5642 - val_loss: 1.1381 - learning_rate: 4.0000e-05
# Epoch 22/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 35s 75ms/step - accuracy: 0.5312 - loss: 1.3705 - val_accuracy: 0.5639 - val_loss: 1.1381 - learning_rate: 4.0000e-05
# Epoch 23/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 873s 2s/step - accuracy: 0.5336 - loss: 1.2434 - val_accuracy: 0.5677 - val_loss: 1.1324 - learning_rate: 4.0000e-05
# Epoch 24/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.5312 - loss: 1.2846 - val_accuracy: 0.5674 - val_loss: 1.1327 - learning_rate: 4.0000e-05
# Epoch 25/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 861s 2s/step - accuracy: 0.5307 - loss: 1.2416 - val_accuracy: 0.5674 - val_loss: 1.1179 - learning_rate: 4.0000e-05
# Epoch 26/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 32s 68ms/step - accuracy: 0.5312 - loss: 1.2825 - val_accuracy: 0.5675 - val_loss: 1.1176 - learning_rate: 4.0000e-05
# Epoch 27/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 932s 2s/step - accuracy: 0.5433 - loss: 1.2250 - val_accuracy: 0.5709 - val_loss: 1.1184 - learning_rate: 4.0000e-05
# Epoch 28/50
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 10:55 1s/step - accuracy: 0.5312 - loss: 1.3435
# Epoch 28: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.5312 - loss: 1.3435 - val_accuracy: 0.5706 - val_loss: 1.1180 - learning_rate: 4.0000e-05
# Epoch 29/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 618s 1s/step - accuracy: 0.5411 - loss: 1.2317 - val_accuracy: 0.5804 - val_loss: 1.1056 - learning_rate: 8.0000e-06
# Epoch 30/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 25s 50ms/step - accuracy: 0.4688 - loss: 1.3667 - val_accuracy: 0.5801 - val_loss: 1.1058 - learning_rate: 8.0000e-06
# Epoch 31/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 646s 1s/step - accuracy: 0.5480 - loss: 1.2104 - val_accuracy: 0.5788 - val_loss: 1.1034 - learning_rate: 8.0000e-06
# Epoch 32/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 27s 58ms/step - accuracy: 0.5312 - loss: 1.2436 - val_accuracy: 0.5790 - val_loss: 1.1033 - learning_rate: 8.0000e-06
# Epoch 33/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 752s 2s/step - accuracy: 0.5499 - loss: 1.2138 - val_accuracy: 0.5829 - val_loss: 1.0976 - learning_rate: 8.0000e-06
# Epoch 34/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 26s 55ms/step - accuracy: 0.6094 - loss: 1.1486 - val_accuracy: 0.5831 - val_loss: 1.0977 - learning_rate: 8.0000e-06
# Epoch 35/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5459 - loss: 1.2185
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 772s 2s/step - accuracy: 0.5459 - loss: 1.2185 - val_accuracy: 0.5838 - val_loss: 1.0977 - learning_rate: 8.0000e-06
# Epoch 36/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.5781 - loss: 1.1102 - val_accuracy: 0.5838 - val_loss: 1.0976 - learning_rate: 1.6000e-06
# Epoch 37/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 660s 1s/step - accuracy: 0.5546 - loss: 1.2085 - val_accuracy: 0.5850 - val_loss: 1.0973 - learning_rate: 1.6000e-06
# Epoch 38/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 33s 69ms/step - accuracy: 0.5625 - loss: 1.0895 - val_accuracy: 0.5848 - val_loss: 1.0973 - learning_rate: 1.6000e-06
# Epoch 39/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5507 - loss: 1.2194
# Epoch 39: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 867s 2s/step - accuracy: 0.5507 - loss: 1.2194 - val_accuracy: 0.5830 - val_loss: 1.0976 - learning_rate: 1.6000e-06
# Epoch 40/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 27s 58ms/step - accuracy: 0.5156 - loss: 1.2707 - val_accuracy: 0.5826 - val_loss: 1.0978 - learning_rate: 3.2000e-07
# Epoch 41/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5454 - loss: 1.2133
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 608s 1s/step - accuracy: 0.5454 - loss: 1.2133 - val_accuracy: 0.5822 - val_loss: 1.0986 - learning_rate: 3.2000e-07
# Epoch 42/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.6250 - loss: 1.1600 - val_accuracy: 0.5824 - val_loss: 1.0987 - learning_rate: 6.4000e-08
# Epoch 43/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5492 - loss: 1.2087
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 526s 1s/step - accuracy: 0.5492 - loss: 1.2087 - val_accuracy: 0.5834 - val_loss: 1.0982 - learning_rate: 6.4000e-08
# Epoch 44/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 40s 86ms/step - accuracy: 0.5000 - loss: 1.2314 - val_accuracy: 0.5838 - val_loss: 1.0983 - learning_rate: 1.2800e-08
# Epoch 45/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5510 - loss: 1.2126
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 940s 2s/step - accuracy: 0.5510 - loss: 1.2126 - val_accuracy: 0.5831 - val_loss: 1.0974 - learning_rate: 1.2800e-08
# Epoch 46/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 54s 114ms/step - accuracy: 0.5469 - loss: 1.2366 - val_accuracy: 0.5829 - val_loss: 1.0975 - learning_rate: 2.5600e-09
# Epoch 47/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5524 - loss: 1.2028
# Epoch 47: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 870s 2s/step - accuracy: 0.5523 - loss: 1.2028 - val_accuracy: 0.5834 - val_loss: 1.0976 - learning_rate: 2.5600e-09
# Epoch 48/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 36s 77ms/step - accuracy: 0.6406 - loss: 1.1060 - val_accuracy: 0.5834 - val_loss: 1.0976 - learning_rate: 5.1200e-10
# Epoch 49/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5544 - loss: 1.2104
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 718s 2s/step - accuracy: 0.5544 - loss: 1.2104 - val_accuracy: 0.5837 - val_loss: 1.0976 - learning_rate: 5.1200e-10
# Epoch 50/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 33s 69ms/step - accuracy: 0.6250 - loss: 1.1026 - val_accuracy: 0.5834 - val_loss: 1.0977 - learning_rate: 1.0240e-10
# Restoring model weights from the end of the best epoch: 37.

# %%
CNN_Score = CNN_Model.evaluate(test_data)

print("    Test Loss: {:.5f}".format(CNN_Score[0]))
print("Test Accuracy: {:.2f}%".format(CNN_Score[1] * 100))
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 31s 267ms/step - accuracy: 0.5222 - loss: 1.2297
#     Test Loss: 1.09614
# Test Accuracy: 58.55%

# %%
CNN_Model.save("CNN_Model_Final_Saved2.0.keras")

# %%
from tensorflow.keras.models import load_model

# Load the saved model
loaded_model = load_model("CNN_Model_Final_Saved.keras")

# Evaluate the model on the test data
CNN_Score = loaded_model.evaluate(test_data)

# Print the results
print("Test Loss: {:.5f}".format(CNN_Score[0]))
print("Test Accuracy: {:.2f}%".format(CNN_Score[1] * 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 loaded_model = load_model("CNN_Model_Final_Saved.keras")
#       6 # Evaluate the model on the test data
# ----> 7 CNN_Score = loaded_model.evaluate(test_data)
#       9 # Print the results
#      10 print("Test Loss: {:.5f}".format(CNN_Score[0]))
#
# NameError: name 'test_data' is not defined

# %%
def plot_curves(history):

    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    accuracy = history.history["accuracy"]
    val_accuracy = history.history["val_accuracy"]

    epochs = range(len(history.history["loss"]))

    plt.figure(figsize=(15,5))

    #plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label = "training_loss")
    plt.plot(epochs, val_loss, label = "val_loss")
    plt.title("Loss")
    plt.xlabel("epochs")
    plt.legend()

    #plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label = "training_accuracy")
    plt.plot(epochs, val_accuracy, label = "val_accuracy")
    plt.title("Accuracy")
    plt.xlabel("epochs")
    plt.legend()
  
  #plt.tight_layout()

# %%
plot_curves(CNN_history)

# %%
CNN_Predictions = CNN_Model.predict(test_data)

# Choosing highest probalbilty class in every prediction 
CNN_Predictions = np.argmax(CNN_Predictions, axis=1)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step

# %%
test_data.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix

fig, ax= plt.subplots(figsize=(15,10))

cm=confusion_matrix(test_data.labels, CNN_Predictions)

sns.heatmap(cm, annot=True, fmt='g', ax=ax)

ax.set_xlabel('Predicted labels',fontsize=15, fontweight='bold')
ax.set_ylabel('True labels', fontsize=15, fontweight='bold')
ax.set_title('CNN Confusion Matrix', fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'CNN Confusion Matrix')

# %%
Emotion_Classes = ['Angry', 
                  'Disgust', 
                  'Fear', 
                  'Happy', 
                  'Neutral', 
                  'Sad', 
                  'Surprise']

# %%
# Shuffling Test Data to show diffrent classes
test_preprocessor = ImageDataGenerator(
        rescale = 1 / 255.,
    )

test_generator = test_preprocessor.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode="rgb",
    shuffle=True,
    batch_size=batch_size,
)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
# Display 10 random pictures from the dataset with their labels

Random_batch = np.random.randint(0, len(test_generator) - 1)

Random_Img_Index = np.random.randint(0, batch_size - 1 , 10)

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(25, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):

    Random_Img = test_generator[Random_batch][0][Random_Img_Index[i]]

    Random_Img_Label = np.argmax(test_generator[Random_batch][1][Random_Img_Index[i]])

    Model_Prediction = np.argmax(CNN_Model.predict( tf.expand_dims(Random_Img, axis=0) , verbose=0))

    ax.imshow(Random_Img)

    if Emotion_Classes[Random_Img_Label] == Emotion_Classes[Model_Prediction]:
          color = "green"
    else:
          color = "red"
    ax.set_title(f"True: {Emotion_Classes[Random_Img_Label]}\nPredicted: {Emotion_Classes[Model_Prediction]}", color=color)
plt.show()
plt.tight_layout()

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam

# Load the model
model = load_model("CNN_Model_Final_Saved.keras")

# Compile the model (if you need metrics for evaluation or further training)
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("Model compiled successfully!")
# Out:
# Model compiled successfully!
